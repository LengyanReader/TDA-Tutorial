# %% [markdown]
# This is a toy example of the use of Mapper algorithm. We will generate two concentric cycles and run the mapper on them. As a filtering function we will select projection to the second coordinate, as a colouring function, projection to the first one. Clustering method will be DBSCAN with some more or less random parameters.

# %%
import kmapper as km
from kmapper import jupyter 
import numpy as np
import sklearn
import matplotlib.pyplot as plt

# %%
#help(km.KeplerMapper)

# %%
import kmapper as km
from sklearn import datasets
data, labels = datasets.make_circles(n_samples=5000, noise=0.03, factor=0.3)

# Initialize
mapper = km.KeplerMapper(verbose=1)
projected_data = data[:,1]  # len
colouring = data[:,0]
# Out:
# KeplerMapper(verbose=1)

# %%
data
len(labels)
labels
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#Here is our dataset:
plot = plt.scatter( data[:,0],data[:,1] )

# %%
#dir(graph)

# %%
#np.array(colouring)
#graph.items

# %%
graph = mapper.map(projected_data,data,
                      clusterer=sklearn.cluster.DBSCAN(eps=0.3, min_samples=15),
                      cover=km.Cover(20, 0.3))

# Visualize it

# color_function 
html = mapper.visualize(graph, path_html="concentric_circles_km.html", #color_values=colouring ,            ##color_values=labels,#np.array(colouring),#colouring,
                 title="make_circles(n_samples=5000, noise=0.03, factor=0.3)")

jupyter.display(path_html="concentric_circles_km.html")
# Out:
# Mapping on data shaped (5000, 2) using lens shaped (5000,)
#
# Creating 20 hypercubes.
#
# Created 46 edges and 46 nodes in 0:00:00.110998.
# Wrote visualization to: concentric_circles_km.html
# <style>
#         .container { width:100% !important; }
#         .output_scroll {height: 800px !important;}
#         </style>
# C:\Users\Administrator\.julia\conda\3\lib\site-packages\IPython\core\display.py:419: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=concentric_circles_km.html width=100%% height=800 frameBorder="0"></iframe>

# %%
#Here is an alternative way of visualizing the mapper graph with mathplotlib:
km.draw_matplotlib(graph, layout="spring")
plt.show()
# Out:
# no display found. Using non-interactive Agg backend
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_20188\3529115389.py:3: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
